# %%
SEQUENCE_LENGTH = 100
LATENT_DIMENSION = 1000
BATCH_SIZE = 16
EPOCHS = 100
SAMPLE_INTERVAL = 1

# %%
from gans_transformer import *

gan = GAN(rows=SEQUENCE_LENGTH)   
     
gan.train(epochs=EPOCHS, batch_size=BATCH_SIZE, sample_interval=SAMPLE_INTERVAL, emotion='Q1')

# Save the generator and discriminator models
gan.generator.save("generator_model_Q1.h5")
gan.discriminator.save("discriminator_model_Q1.h5")
# Out:
# 2023-12-06 06:48:31.938144: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-06 06:48:31.984747: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-06 06:48:31.984796: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-06 06:48:31.986329: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-06 06:48:31.994208: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-06 06:48:31.994983: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-06 06:48:33.218787: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-06 06:48:35.318453: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 512)          1052672
#
#  bidirectional (Bidirection  (None, 1024)              4198400
#  al)
#
#  dense (Dense)               (None, 512)               524800
#
#  leaky_re_lu (LeakyReLU)     (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 256)               0
#
#  dense_2 (Dense)             (None, 100)               25700
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 100)               0
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 5933001 (22.63 MB)
# Trainable params: 5933001 (22.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 256)               256256
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 256)               0
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_5 (Dense)             (None, 512)               131584
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 512)               0
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_6 (Dense)             (None, 1024)              525312
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 1024)              0
#
#  batch_normalization_2 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dense_7 (Dense)             (None, 100)               102500
#
#  reshape (Reshape)           (None, 100, 1)            0
#
# =================================================================
# Total params: 1022820 (3.90 MB)
# Trainable params: 1019236 (3.89 MB)
# Non-trainable params: 3584 (14.00 KB)
# _________________________________________________________________
# Parsing midis_emopia/Q1_9v2WSpn4FCw_10.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_3.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_3.mid
# Parsing midis_emopia/Q1_ZgT7yq2jsBk_0.mid
# /home/codespace/.python/current/lib/python3.10/site-packages/music21/stream/base.py:3694: Music21DeprecationWarning: .flat is deprecated.  Call .flatten() instead
#   return self.iter().getElementsByClass(classFilterList)
# Parsing midis_emopia/Q1_Jn9r0avp0fY_3.mid
# Parsing midis_emopia/Q1_POaIGvLsp5M_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_2.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_2.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_1.mid
# Parsing midis_emopia/Q1_3ahg_eQZhxs_1.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_3.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_4.mid
# Parsing midis_emopia/Q1_6Uf9XBUD3wE_0.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_2.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_1.mid
# Parsing midis_emopia/Q1_Cg2u_Ldjv8g_0.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_1.mid
# Parsing midis_emopia/Q1_9Yb9OEVwups_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_3.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_0.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_4.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_2.mid
# Parsing midis_emopia/Q1_K6OFDxBU370_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_0.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_3.mid
# Parsing midis_emopia/Q1_4ydjOX3pWds_0.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_5.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_2.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_12.mid
# Parsing midis_emopia/Q1_xrhWli_R98g_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_7.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_1.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_3.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_2.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_2.mid
# Parsing midis_emopia/Q1_KxlqB3j0zys_1.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_2.mid
# Parsing midis_emopia/Q1_UYh88SRZC24_0.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_0.mid
# Parsing midis_emopia/Q1_UJcnNfeCN1c_2.mid
# Parsing midis_emopia/Q1_gwmVjvR-sVs_1.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_2.mid
# Parsing midis_emopia/Q1_UJcnNfeCN1c_3.mid
# Parsing midis_emopia/Q1_5NW0zDu6IYM_2.mid
# Parsing midis_emopia/Q1_UYh88SRZC24_1.mid
# Parsing midis_emopia/Q1_Ie5koh4qvJc_12.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_0.mid
# Parsing midis_emopia/Q1_Xsn9zT-05ns_1.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_0.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_1.mid
# Parsing midis_emopia/Q1_Xsn9zT-05ns_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_0.mid
# Parsing midis_emopia/Q1_Cg2u_Ldjv8g_1.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_2.mid
# Parsing midis_emopia/Q1_K6OFDxBU370_0.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_0.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_2.mid
# Parsing midis_emopia/Q1_sUJ4a74Skk8_0.mid
# Parsing midis_emopia/Q1_e8NQ2NH0nc8_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_15.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_3.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_1.mid
# Parsing midis_emopia/Q1_T92R7xjce34_1.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_2.mid
# Parsing midis_emopia/Q1_xrhWli_R98g_1.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_1.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_1.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_1.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_3.mid
# Parsing midis_emopia/Q1_BGf5nCdzPOc_0.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_0.mid
# Parsing midis_emopia/Q1_mX-xs3OVhTs_1.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_5.mid
# Parsing midis_emopia/Q1_QwsQ8ejbMKg_0.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_5.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_0.mid
# Parsing midis_emopia/Q1__SJQaaRzD-A_1.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_1.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_4.mid
# Parsing midis_emopia/Q1_s6-SbDSZzEU_0.mid
# Parsing midis_emopia/Q1_POaIGvLsp5M_0.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_0.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_2.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_2.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_2.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_1.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_3.mid
# Parsing midis_emopia/Q1_4dXC1cC7crw_1.mid
# Parsing midis_emopia/Q1_e8NQ2NH0nc8_0.mid
# Parsing midis_emopia/Q1__8v0MFBZoco_0.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_1.mid
# Parsing midis_emopia/Q1_6wFJhmhNeeg_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_3.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_0.mid
# Parsing midis_emopia/Q1_Fc1qk52SaKY_0.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_1.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_2.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_1.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_2.mid
# Parsing midis_emopia/Q1_SlsXsqotUis_0.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_1.mid
# Parsing midis_emopia/Q1_cB-Xh8H_7-Q_0.mid
# Parsing midis_emopia/Q1_J6X3rVU1H-c_1.mid
# Parsing midis_emopia/Q1_60LLKmpgzRM_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_9.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_13.mid
# Parsing midis_emopia/Q1_BGf5nCdzPOc_1.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_4.mid
# Parsing midis_emopia/Q1_uqRLEByE6pU_2.mid
# Parsing midis_emopia/Q1_IH2KrGjKXw0_3.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_5.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_1.mid
# Parsing midis_emopia/Q1_Ie5koh4qvJc_6.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_0.mid
# Parsing midis_emopia/Q1_o5AIp2Yc01M_1.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_1.mid
# Parsing midis_emopia/Q1__BK2o77sTc0_1.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_0.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_10.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_0.mid
# Parsing midis_emopia/Q1_GbUV3TXUzeQ_2.mid
# Parsing midis_emopia/Q1_8rupdevqfuI_1.mid
# Parsing midis_emopia/Q1_k4dxAlI5N-k_0.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_0.mid
# Parsing midis_emopia/Q1_k4dxAlI5N-k_1.mid
# Parsing midis_emopia/Q1_NGE9ynTJABg_2.mid
# Parsing midis_emopia/Q1_gwmVjvR-sVs_0.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_0.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_3.mid
# Parsing midis_emopia/Q1_uqRLEByE6pU_0.mid
# Parsing midis_emopia/Q1_iFgSjUqI7iM_0.mid
# Parsing midis_emopia/Q1_NP0lwB-_-og_1.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_0.mid
# Parsing midis_emopia/Q1_GbUV3TXUzeQ_1.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_2.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_3.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_1.mid
# Parsing midis_emopia/Q1_biROWEwkDQQ_3.mid
# Parsing midis_emopia/Q1_Wy2-my19YnY_1.mid
# Parsing midis_emopia/Q1_r6laJv1-HMg_0.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_5.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_6.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_3.mid
# Parsing midis_emopia/Q1_wnB2cjd6zbE_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_1.mid
# Parsing midis_emopia/Q1_JYVXM0qNQAg_2.mid
# Parsing midis_emopia/Q1_6Uf9XBUD3wE_1.mid
# Parsing midis_emopia/Q1_4ydjOX3pWds_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_1.mid
# Parsing midis_emopia/Q1_3ahg_eQZhxs_0.mid
# Parsing midis_emopia/Q1_sZe3IB1OVfw_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_2.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_6.mid
# Parsing midis_emopia/Q1_ldCQ6N9G6Mk_2.mid
# Parsing midis_emopia/Q1_5Ju9q1N2x0E_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_1.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_1.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_2.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_0.mid
# Parsing midis_emopia/Q1_NGE9ynTJABg_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_0.mid
# Parsing midis_emopia/Q1_XC_SiJszQx0_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_8.mid
# Parsing midis_emopia/Q1_KxlqB3j0zys_0.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_1.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_2.mid
# Parsing midis_emopia/Q1_DX1IK3z1w10_1.mid
# Parsing midis_emopia/Q1_sZe3IB1OVfw_0.mid
# Parsing midis_emopia/Q1_qlbazHayULg_8.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_4.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_0.mid
# Parsing midis_emopia/Q1_osxmQReE_2o_0.mid
# Parsing midis_emopia/Q1_4dXC1cC7crw_0.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_3.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_4.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_1.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_0.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_0.mid
# Parsing midis_emopia/Q1_8rupdevqfuI_2.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_1.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_0.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_2.mid
# Parsing midis_emopia/Q1_JYVXM0qNQAg_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_2.mid
# Parsing midis_emopia/Q1_8izVTDgBQPc_1.mid
# Parsing midis_emopia/Q1_o5AIp2Yc01M_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_1.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_2.mid
# Parsing midis_emopia/Q1_Wy2-my19YnY_0.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_14.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_0.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_4.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_0.mid
# Parsing midis_emopia/Q1_iFgSjUqI7iM_1.mid
# Parsing midis_emopia/Q1__8v0MFBZoco_1.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_3.mid
# Parsing midis_emopia/Q1_s6-SbDSZzEU_1.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_0.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_3.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_4.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_1.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_2.mid
# Parsing midis_emopia/Q1_J6X3rVU1H-c_2.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_0.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_0.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_1.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_2.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_11.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_0.mid
# Parsing midis_emopia/Q1__SJQaaRzD-A_0.mid
# Parsing midis_emopia/Q1__BK2o77sTc0_0.mid
# Parsing midis_emopia/Q1_gSwv8hZGM-s_1.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_2.mid
# Parsing midis_emopia/Q1_gSwv8hZGM-s_0.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_2.mid
# Parsing midis_emopia/Q1_Fc1qk52SaKY_1.mid
# Parsing midis_emopia/Q1_mX-xs3OVhTs_0.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_1.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_0.mid
# Parsing midis_emopia/Q1_miqLU2739dk_1.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_1.mid
# Parsing midis_emopia/Q1_V3Y9L4UOcpk_2.mid
# Parsing midis_emopia/Q1_nOIBJHkqrE8_0.mid
# 1/1 [==============================] - 0s 168ms/step
# 0 [D loss: 0.694455, acc.: 34.38%] [G loss: 0.690403]
# 1/1 [==============================] - 0s 20ms/step
# 1 [D loss: 0.683124, acc.: 59.38%] [G loss: 0.693108]
# 1/1 [==============================] - 0s 19ms/step
# 2 [D loss: 0.665756, acc.: 68.75%] [G loss: 0.690851]
# 1/1 [==============================] - 0s 19ms/step
# 3 [D loss: 0.625936, acc.: 68.75%] [G loss: 0.688162]
# 1/1 [==============================] - 0s 19ms/step
# 4 [D loss: 0.560147, acc.: 68.75%] [G loss: 0.747101]
# 1/1 [==============================] - 0s 20ms/step
# 5 [D loss: 0.447500, acc.: 84.38%] [G loss: 0.897963]
# 1/1 [==============================] - 0s 20ms/step
# 6 [D loss: 0.223844, acc.: 96.88%] [G loss: 2.260109]
# 1/1 [==============================] - 0s 19ms/step
# 7 [D loss: 0.025166, acc.: 100.00%] [G loss: 5.685620]
# 1/1 [==============================] - 0s 20ms/step
# 8 [D loss: 0.189249, acc.: 96.88%] [G loss: 6.767249]
# 1/1 [==============================] - 0s 19ms/step
# 9 [D loss: 0.111601, acc.: 96.88%] [G loss: 2.609410]
# 1/1 [==============================] - 0s 21ms/step
# 10 [D loss: 0.172759, acc.: 93.75%] [G loss: 6.296509]
# 1/1 [==============================] - 0s 23ms/step
# 11 [D loss: 0.526905, acc.: 78.12%] [G loss: 6.101352]
# 1/1 [==============================] - 0s 21ms/step
# 12 [D loss: 0.155421, acc.: 96.88%] [G loss: 7.580083]
# 1/1 [==============================] - 0s 18ms/step
# 13 [D loss: 0.478379, acc.: 96.88%] [G loss: 1.686146]
# 1/1 [==============================] - 0s 20ms/step
# 14 [D loss: 0.207094, acc.: 100.00%] [G loss: 3.537799]
# 1/1 [==============================] - 0s 19ms/step
# 15 [D loss: 0.221211, acc.: 90.62%] [G loss: 5.248511]
# 1/1 [==============================] - 0s 21ms/step
# 16 [D loss: 0.389281, acc.: 90.62%] [G loss: 2.575976]
# 1/1 [==============================] - 0s 19ms/step
# 17 [D loss: 0.214044, acc.: 90.62%] [G loss: 3.678426]
# 1/1 [==============================] - 0s 19ms/step
# 18 [D loss: 0.227310, acc.: 87.50%] [G loss: 4.750546]
# 1/1 [==============================] - 0s 18ms/step
# 19 [D loss: 0.209104, acc.: 90.62%] [G loss: 3.809443]
# 1/1 [==============================] - 0s 19ms/step
# 20 [D loss: 0.075398, acc.: 100.00%] [G loss: 6.312728]
# 1/1 [==============================] - 0s 20ms/step
# 21 [D loss: 0.182525, acc.: 90.62%] [G loss: 5.830149]
# 1/1 [==============================] - 0s 25ms/step
# 22 [D loss: 0.616111, acc.: 84.38%] [G loss: 1.733040]
# 1/1 [==============================] - 0s 20ms/step
# 23 [D loss: 0.297922, acc.: 87.50%] [G loss: 2.123667]
# 1/1 [==============================] - 0s 20ms/step
# 24 [D loss: 0.347411, acc.: 87.50%] [G loss: 2.293008]
# 1/1 [==============================] - 0s 42ms/step
# 25 [D loss: 0.160341, acc.: 96.88%] [G loss: 3.118941]
# 1/1 [==============================] - 0s 18ms/step
# 26 [D loss: 0.070223, acc.: 100.00%] [G loss: 5.142478]
# 1/1 [==============================] - 0s 19ms/step
# 27 [D loss: 0.113122, acc.: 93.75%] [G loss: 5.465047]
# 1/1 [==============================] - 0s 19ms/step
# 28 [D loss: 0.310364, acc.: 90.62%] [G loss: 3.060151]
# 1/1 [==============================] - 0s 25ms/step
# 29 [D loss: 0.172953, acc.: 90.62%] [G loss: 3.247726]
# 1/1 [==============================] - 0s 19ms/step
# 30 [D loss: 0.157642, acc.: 96.88%] [G loss: 3.517356]
# 1/1 [==============================] - 0s 21ms/step
# 31 [D loss: 0.106257, acc.: 96.88%] [G loss: 5.186800]
# 1/1 [==============================] - 0s 19ms/step
# 32 [D loss: 0.291398, acc.: 87.50%] [G loss: 5.235501]
# 1/1 [==============================] - 0s 19ms/step
# 33 [D loss: 0.071982, acc.: 96.88%] [G loss: 5.535649]
# 1/1 [==============================] - 0s 24ms/step
# 34 [D loss: 0.275784, acc.: 87.50%] [G loss: 3.226853]
# 1/1 [==============================] - 0s 19ms/step
# 35 [D loss: 0.106377, acc.: 93.75%] [G loss: 3.471306]
# 1/1 [==============================] - 0s 19ms/step
# 36 [D loss: 0.124083, acc.: 96.88%] [G loss: 3.997699]
# 1/1 [==============================] - 0s 19ms/step
# 37 [D loss: 0.198520, acc.: 90.62%] [G loss: 4.547235]
# 1/1 [==============================] - 0s 19ms/step
# 38 [D loss: 0.232660, acc.: 90.62%] [G loss: 5.118707]
# 1/1 [==============================] - 0s 30ms/step
# 39 [D loss: 0.193492, acc.: 87.50%] [G loss: 4.687128]
# 1/1 [==============================] - 0s 21ms/step
# 40 [D loss: 0.240150, acc.: 90.62%] [G loss: 5.485528]
# 1/1 [==============================] - 0s 19ms/step
# 41 [D loss: 0.191793, acc.: 93.75%] [G loss: 7.144303]
# 1/1 [==============================] - 0s 20ms/step
# 42 [D loss: 0.281157, acc.: 90.62%] [G loss: 3.852729]
# 1/1 [==============================] - 0s 19ms/step
# 43 [D loss: 0.268776, acc.: 90.62%] [G loss: 3.290724]
# 1/1 [==============================] - 0s 21ms/step
# 44 [D loss: 0.164596, acc.: 93.75%] [G loss: 4.899667]
# 1/1 [==============================] - 0s 19ms/step
# 45 [D loss: 0.258277, acc.: 90.62%] [G loss: 5.080123]
# 1/1 [==============================] - 0s 20ms/step
# 46 [D loss: 0.197776, acc.: 93.75%] [G loss: 4.679658]
# 1/1 [==============================] - 0s 19ms/step
# 47 [D loss: 0.066623, acc.: 100.00%] [G loss: 5.597541]
# 1/1 [==============================] - 0s 18ms/step
# 48 [D loss: 0.056430, acc.: 100.00%] [G loss: 7.645768]
# 1/1 [==============================] - 0s 19ms/step
# 49 [D loss: 0.240598, acc.: 93.75%] [G loss: 4.222397]
# 1/1 [==============================] - 0s 19ms/step
# 50 [D loss: 0.166517, acc.: 96.88%] [G loss: 5.294375]
# 1/1 [==============================] - 0s 19ms/step
# 51 [D loss: 0.430530, acc.: 84.38%] [G loss: 3.790132]
# 1/1 [==============================] - 0s 19ms/step
# 52 [D loss: 0.249943, acc.: 87.50%] [G loss: 3.163708]
# 1/1 [==============================] - 0s 20ms/step
# 53 [D loss: 0.267261, acc.: 87.50%] [G loss: 3.332222]
# 1/1 [==============================] - 0s 19ms/step
# 54 [D loss: 0.337362, acc.: 87.50%] [G loss: 3.311489]
# 1/1 [==============================] - 0s 20ms/step
# 55 [D loss: 0.217623, acc.: 93.75%] [G loss: 3.502258]
# 1/1 [==============================] - 0s 19ms/step
# 56 [D loss: 0.178204, acc.: 93.75%] [G loss: 4.436082]
# 1/1 [==============================] - 0s 19ms/step
# 57 [D loss: 0.211061, acc.: 90.62%] [G loss: 4.648967]
# 1/1 [==============================] - 0s 26ms/step
# 58 [D loss: 0.256608, acc.: 87.50%] [G loss: 3.834001]
# 1/1 [==============================] - 0s 20ms/step
# 59 [D loss: 0.178919, acc.: 93.75%] [G loss: 3.910138]
# 1/1 [==============================] - 0s 21ms/step
# 60 [D loss: 0.364681, acc.: 84.38%] [G loss: 3.408627]
# 1/1 [==============================] - 0s 20ms/step
# 61 [D loss: 0.349094, acc.: 81.25%] [G loss: 2.944813]
# 1/1 [==============================] - 0s 20ms/step
# 62 [D loss: 0.267808, acc.: 87.50%] [G loss: 3.785984]
# 1/1 [==============================] - 0s 19ms/step
# 63 [D loss: 0.175640, acc.: 93.75%] [G loss: 4.419030]
# 1/1 [==============================] - 0s 19ms/step
# 64 [D loss: 0.187787, acc.: 93.75%] [G loss: 6.345715]
# 1/1 [==============================] - 0s 21ms/step
# 65 [D loss: 0.131102, acc.: 90.62%] [G loss: 5.647786]
# 1/1 [==============================] - 0s 19ms/step
# 66 [D loss: 0.161330, acc.: 93.75%] [G loss: 6.346696]
# 1/1 [==============================] - 0s 19ms/step
# 67 [D loss: 0.288887, acc.: 93.75%] [G loss: 6.153823]
# 1/1 [==============================] - 0s 19ms/step
# 68 [D loss: 0.314353, acc.: 81.25%] [G loss: 3.197528]
# 1/1 [==============================] - 0s 27ms/step
# 69 [D loss: 0.211851, acc.: 93.75%] [G loss: 3.579731]
# 1/1 [==============================] - 0s 25ms/step
# 70 [D loss: 0.148941, acc.: 96.88%] [G loss: 7.447903]
# 1/1 [==============================] - 0s 20ms/step
# 71 [D loss: 0.185188, acc.: 90.62%] [G loss: 7.237502]
# 1/1 [==============================] - 0s 21ms/step
# 72 [D loss: 0.050951, acc.: 100.00%] [G loss: 7.716070]
# 1/1 [==============================] - 0s 19ms/step
# 73 [D loss: 0.118358, acc.: 93.75%] [G loss: 6.899517]
# 1/1 [==============================] - 0s 18ms/step
# 74 [D loss: 0.144770, acc.: 93.75%] [G loss: 5.695692]
# 1/1 [==============================] - 0s 19ms/step
# 75 [D loss: 0.200201, acc.: 87.50%] [G loss: 6.134359]
# 1/1 [==============================] - 0s 20ms/step
# 76 [D loss: 0.329439, acc.: 87.50%] [G loss: 12.603647]
# 1/1 [==============================] - 0s 20ms/step
# 77 [D loss: 0.145900, acc.: 90.62%] [G loss: 16.210247]
# 1/1 [==============================] - 0s 18ms/step
# 78 [D loss: 0.113032, acc.: 93.75%] [G loss: 19.479244]
# 1/1 [==============================] - 0s 24ms/step
# 79 [D loss: 0.128854, acc.: 93.75%] [G loss: 20.158140]
# 1/1 [==============================] - 0s 19ms/step
# 80 [D loss: 1.602028, acc.: 90.62%] [G loss: 3.308488]
# 1/1 [==============================] - 0s 20ms/step
# 81 [D loss: 0.210009, acc.: 93.75%] [G loss: 3.296016]
# 1/1 [==============================] - 0s 21ms/step
# 82 [D loss: 0.419730, acc.: 81.25%] [G loss: 4.198575]
# 1/1 [==============================] - 0s 18ms/step
# 83 [D loss: 0.434016, acc.: 84.38%] [G loss: 1.715001]
# 1/1 [==============================] - 0s 20ms/step
# 84 [D loss: 0.358943, acc.: 87.50%] [G loss: 1.857429]
# 1/1 [==============================] - 0s 21ms/step
# 85 [D loss: 0.403938, acc.: 87.50%] [G loss: 1.889587]
# 1/1 [==============================] - 0s 20ms/step
# 86 [D loss: 0.337355, acc.: 81.25%] [G loss: 2.245569]
# 1/1 [==============================] - 0s 20ms/step
# 87 [D loss: 0.224473, acc.: 93.75%] [G loss: 3.460587]
# 1/1 [==============================] - 0s 19ms/step
# 88 [D loss: 0.218645, acc.: 93.75%] [G loss: 5.889174]
# 1/1 [==============================] - 0s 19ms/step
# 89 [D loss: 0.531403, acc.: 84.38%] [G loss: 2.906631]
# 1/1 [==============================] - 0s 19ms/step
# 90 [D loss: 0.543583, acc.: 75.00%] [G loss: 2.405779]
# 1/1 [==============================] - 0s 20ms/step
# 91 [D loss: 0.284099, acc.: 87.50%] [G loss: 2.428574]
# 1/1 [==============================] - 0s 19ms/step
# 92 [D loss: 0.464405, acc.: 75.00%] [G loss: 2.188850]
# 1/1 [==============================] - 0s 18ms/step
# 93 [D loss: 0.419702, acc.: 81.25%] [G loss: 2.153731]
# 1/1 [==============================] - 0s 19ms/step
# 94 [D loss: 0.475490, acc.: 81.25%] [G loss: 2.339556]
# 1/1 [==============================] - 0s 19ms/step
# 95 [D loss: 0.332973, acc.: 90.62%] [G loss: 2.675474]
# 1/1 [==============================] - 0s 19ms/step
# 96 [D loss: 0.333686, acc.: 84.38%] [G loss: 2.728497]
# 1/1 [==============================] - 0s 27ms/step
# 97 [D loss: 0.385269, acc.: 84.38%] [G loss: 3.264188]
# 1/1 [==============================] - 0s 20ms/step
# 98 [D loss: 0.307934, acc.: 90.62%] [G loss: 3.511020]
# 1/1 [==============================] - 0s 19ms/step
# 99 [D loss: 0.479566, acc.: 81.25%] [G loss: 5.434574]
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /home/codespace/.python/current/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from gans_generation import * 
from gans_transformer import *
from tensorflow.keras.models import load_model
from music21 import stream, note, chord, instrument

generator_model = load_model("generator_model_Q1.h5")
    
# Load the processed notes and get the number of unique pitches
notes = get_notes(emotion='Q1')
n_vocab = len(set(notes))

# Generate new music sequence
for i in range(5):
    generated_music = generate_music(generator_model, LATENT_DIMENSION, n_vocab)
    
    # Create a MIDI file from the generated music
    create_midi(generated_music, filename="generated_music_Q1_" + str(i))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Parsing midis_emopia/Q1_9v2WSpn4FCw_10.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_3.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_3.mid
# Parsing midis_emopia/Q1_ZgT7yq2jsBk_0.mid
# /home/codespace/.python/current/lib/python3.10/site-packages/music21/stream/base.py:3694: Music21DeprecationWarning: .flat is deprecated.  Call .flatten() instead
#   return self.iter().getElementsByClass(classFilterList)
# Parsing midis_emopia/Q1_Jn9r0avp0fY_3.mid
# Parsing midis_emopia/Q1_POaIGvLsp5M_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_2.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_2.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_1.mid
# Parsing midis_emopia/Q1_3ahg_eQZhxs_1.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_3.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_4.mid
# Parsing midis_emopia/Q1_6Uf9XBUD3wE_0.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_2.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_1.mid
# Parsing midis_emopia/Q1_Cg2u_Ldjv8g_0.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_1.mid
# Parsing midis_emopia/Q1_9Yb9OEVwups_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_3.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_0.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_4.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_2.mid
# Parsing midis_emopia/Q1_K6OFDxBU370_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_0.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_3.mid
# Parsing midis_emopia/Q1_4ydjOX3pWds_0.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_5.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_2.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_12.mid
# Parsing midis_emopia/Q1_xrhWli_R98g_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_7.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_1.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_3.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_2.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_2.mid
# Parsing midis_emopia/Q1_KxlqB3j0zys_1.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_2.mid
# Parsing midis_emopia/Q1_UYh88SRZC24_0.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_0.mid
# Parsing midis_emopia/Q1_UJcnNfeCN1c_2.mid
# Parsing midis_emopia/Q1_gwmVjvR-sVs_1.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_2.mid
# Parsing midis_emopia/Q1_UJcnNfeCN1c_3.mid
# Parsing midis_emopia/Q1_5NW0zDu6IYM_2.mid
# Parsing midis_emopia/Q1_UYh88SRZC24_1.mid
# Parsing midis_emopia/Q1_Ie5koh4qvJc_12.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_0.mid
# Parsing midis_emopia/Q1_Xsn9zT-05ns_1.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_0.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_1.mid
# Parsing midis_emopia/Q1_Xsn9zT-05ns_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_0.mid
# Parsing midis_emopia/Q1_Cg2u_Ldjv8g_1.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_2.mid
# Parsing midis_emopia/Q1_K6OFDxBU370_0.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_0.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_2.mid
# Parsing midis_emopia/Q1_sUJ4a74Skk8_0.mid
# Parsing midis_emopia/Q1_e8NQ2NH0nc8_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_15.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_3.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_1.mid
# Parsing midis_emopia/Q1_T92R7xjce34_1.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_2.mid
# Parsing midis_emopia/Q1_xrhWli_R98g_1.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_1.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_1.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_1.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_3.mid
# Parsing midis_emopia/Q1_BGf5nCdzPOc_0.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_0.mid
# Parsing midis_emopia/Q1_mX-xs3OVhTs_1.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_5.mid
# Parsing midis_emopia/Q1_QwsQ8ejbMKg_0.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_5.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_0.mid
# Parsing midis_emopia/Q1__SJQaaRzD-A_1.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_1.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_4.mid
# Parsing midis_emopia/Q1_s6-SbDSZzEU_0.mid
# Parsing midis_emopia/Q1_POaIGvLsp5M_0.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_0.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_2.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_2.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_2.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_1.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_3.mid
# Parsing midis_emopia/Q1_4dXC1cC7crw_1.mid
# Parsing midis_emopia/Q1_e8NQ2NH0nc8_0.mid
# Parsing midis_emopia/Q1__8v0MFBZoco_0.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_1.mid
# Parsing midis_emopia/Q1_6wFJhmhNeeg_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_3.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_0.mid
# Parsing midis_emopia/Q1_Fc1qk52SaKY_0.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_1.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_2.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_1.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_2.mid
# Parsing midis_emopia/Q1_SlsXsqotUis_0.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_1.mid
# Parsing midis_emopia/Q1_cB-Xh8H_7-Q_0.mid
# Parsing midis_emopia/Q1_J6X3rVU1H-c_1.mid
# Parsing midis_emopia/Q1_60LLKmpgzRM_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_9.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_13.mid
# Parsing midis_emopia/Q1_BGf5nCdzPOc_1.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_4.mid
# Parsing midis_emopia/Q1_uqRLEByE6pU_2.mid
# Parsing midis_emopia/Q1_IH2KrGjKXw0_3.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_5.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_1.mid
# Parsing midis_emopia/Q1_Ie5koh4qvJc_6.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_0.mid
# Parsing midis_emopia/Q1_o5AIp2Yc01M_1.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_1.mid
# Parsing midis_emopia/Q1__BK2o77sTc0_1.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_0.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_10.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_0.mid
# Parsing midis_emopia/Q1_GbUV3TXUzeQ_2.mid
# Parsing midis_emopia/Q1_8rupdevqfuI_1.mid
# Parsing midis_emopia/Q1_k4dxAlI5N-k_0.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_0.mid
# Parsing midis_emopia/Q1_k4dxAlI5N-k_1.mid
# Parsing midis_emopia/Q1_NGE9ynTJABg_2.mid
# Parsing midis_emopia/Q1_gwmVjvR-sVs_0.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_0.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_3.mid
# Parsing midis_emopia/Q1_uqRLEByE6pU_0.mid
# Parsing midis_emopia/Q1_iFgSjUqI7iM_0.mid
# Parsing midis_emopia/Q1_NP0lwB-_-og_1.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_0.mid
# Parsing midis_emopia/Q1_GbUV3TXUzeQ_1.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_2.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_3.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_1.mid
# Parsing midis_emopia/Q1_biROWEwkDQQ_3.mid
# Parsing midis_emopia/Q1_Wy2-my19YnY_1.mid
# Parsing midis_emopia/Q1_r6laJv1-HMg_0.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_5.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_6.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_3.mid
# Parsing midis_emopia/Q1_wnB2cjd6zbE_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_1.mid
# Parsing midis_emopia/Q1_JYVXM0qNQAg_2.mid
# Parsing midis_emopia/Q1_6Uf9XBUD3wE_1.mid
# Parsing midis_emopia/Q1_4ydjOX3pWds_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_1.mid
# Parsing midis_emopia/Q1_3ahg_eQZhxs_0.mid
# Parsing midis_emopia/Q1_sZe3IB1OVfw_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_2.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_6.mid
# Parsing midis_emopia/Q1_ldCQ6N9G6Mk_2.mid
# Parsing midis_emopia/Q1_5Ju9q1N2x0E_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_1.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_1.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_2.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_0.mid
# Parsing midis_emopia/Q1_NGE9ynTJABg_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_0.mid
# Parsing midis_emopia/Q1_XC_SiJszQx0_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_8.mid
# Parsing midis_emopia/Q1_KxlqB3j0zys_0.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_1.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_2.mid
# Parsing midis_emopia/Q1_DX1IK3z1w10_1.mid
# Parsing midis_emopia/Q1_sZe3IB1OVfw_0.mid
# Parsing midis_emopia/Q1_qlbazHayULg_8.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_4.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_0.mid
# Parsing midis_emopia/Q1_osxmQReE_2o_0.mid
# Parsing midis_emopia/Q1_4dXC1cC7crw_0.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_3.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_4.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_1.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_0.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_0.mid
# Parsing midis_emopia/Q1_8rupdevqfuI_2.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_1.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_0.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_2.mid
# Parsing midis_emopia/Q1_JYVXM0qNQAg_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_2.mid
# Parsing midis_emopia/Q1_8izVTDgBQPc_1.mid
# Parsing midis_emopia/Q1_o5AIp2Yc01M_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_1.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_2.mid
# Parsing midis_emopia/Q1_Wy2-my19YnY_0.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_14.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_0.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_4.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_0.mid
# Parsing midis_emopia/Q1_iFgSjUqI7iM_1.mid
# Parsing midis_emopia/Q1__8v0MFBZoco_1.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_3.mid
# Parsing midis_emopia/Q1_s6-SbDSZzEU_1.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_0.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_3.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_4.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_1.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_2.mid
# Parsing midis_emopia/Q1_J6X3rVU1H-c_2.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_0.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_0.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_1.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_2.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_11.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_0.mid
# Parsing midis_emopia/Q1__SJQaaRzD-A_0.mid
# Parsing midis_emopia/Q1__BK2o77sTc0_0.mid
# Parsing midis_emopia/Q1_gSwv8hZGM-s_1.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_2.mid
# Parsing midis_emopia/Q1_gSwv8hZGM-s_0.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_2.mid
# Parsing midis_emopia/Q1_Fc1qk52SaKY_1.mid
# Parsing midis_emopia/Q1_mX-xs3OVhTs_0.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_1.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_0.mid
# Parsing midis_emopia/Q1_miqLU2739dk_1.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_1.mid
# Parsing midis_emopia/Q1_V3Y9L4UOcpk_2.mid
# Parsing midis_emopia/Q1_nOIBJHkqrE8_0.mid
# 1/1 [==============================] - 0s 110ms/step
# Parsing midis_emopia/Q1_9v2WSpn4FCw_10.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_3.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_3.mid
# Parsing midis_emopia/Q1_ZgT7yq2jsBk_0.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_3.mid
# Parsing midis_emopia/Q1_POaIGvLsp5M_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_2.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_2.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_1.mid
# Parsing midis_emopia/Q1_3ahg_eQZhxs_1.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_3.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_4.mid
# Parsing midis_emopia/Q1_6Uf9XBUD3wE_0.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_2.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_1.mid
# Parsing midis_emopia/Q1_Cg2u_Ldjv8g_0.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_1.mid
# Parsing midis_emopia/Q1_9Yb9OEVwups_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_3.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_0.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_4.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_2.mid
# Parsing midis_emopia/Q1_K6OFDxBU370_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_0.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_3.mid
# Parsing midis_emopia/Q1_4ydjOX3pWds_0.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_5.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_2.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_12.mid
# Parsing midis_emopia/Q1_xrhWli_R98g_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_7.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_1.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_3.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_2.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_2.mid
# Parsing midis_emopia/Q1_KxlqB3j0zys_1.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_2.mid
# Parsing midis_emopia/Q1_UYh88SRZC24_0.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_0.mid
# Parsing midis_emopia/Q1_UJcnNfeCN1c_2.mid
# Parsing midis_emopia/Q1_gwmVjvR-sVs_1.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_2.mid
# Parsing midis_emopia/Q1_UJcnNfeCN1c_3.mid
# Parsing midis_emopia/Q1_5NW0zDu6IYM_2.mid
# Parsing midis_emopia/Q1_UYh88SRZC24_1.mid
# Parsing midis_emopia/Q1_Ie5koh4qvJc_12.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_0.mid
# Parsing midis_emopia/Q1_Xsn9zT-05ns_1.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_0.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_1.mid
# Parsing midis_emopia/Q1_Xsn9zT-05ns_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_0.mid
# Parsing midis_emopia/Q1_Cg2u_Ldjv8g_1.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_2.mid
# Parsing midis_emopia/Q1_K6OFDxBU370_0.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_0.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_2.mid
# Parsing midis_emopia/Q1_sUJ4a74Skk8_0.mid
# Parsing midis_emopia/Q1_e8NQ2NH0nc8_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_15.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_3.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_1.mid
# Parsing midis_emopia/Q1_T92R7xjce34_1.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_2.mid
# Parsing midis_emopia/Q1_xrhWli_R98g_1.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_1.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_1.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_1.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_3.mid
# Parsing midis_emopia/Q1_BGf5nCdzPOc_0.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_0.mid
# Parsing midis_emopia/Q1_mX-xs3OVhTs_1.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_5.mid
# Parsing midis_emopia/Q1_QwsQ8ejbMKg_0.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_5.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_0.mid
# Parsing midis_emopia/Q1__SJQaaRzD-A_1.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_1.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_4.mid
# Parsing midis_emopia/Q1_s6-SbDSZzEU_0.mid
# Parsing midis_emopia/Q1_POaIGvLsp5M_0.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_0.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_2.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_2.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_2.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_1.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_3.mid
# Parsing midis_emopia/Q1_4dXC1cC7crw_1.mid
# Parsing midis_emopia/Q1_e8NQ2NH0nc8_0.mid
# Parsing midis_emopia/Q1__8v0MFBZoco_0.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_1.mid
# Parsing midis_emopia/Q1_6wFJhmhNeeg_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_3.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_0.mid
# Parsing midis_emopia/Q1_Fc1qk52SaKY_0.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_1.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_2.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_1.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_2.mid
# Parsing midis_emopia/Q1_SlsXsqotUis_0.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_1.mid
# Parsing midis_emopia/Q1_cB-Xh8H_7-Q_0.mid
# Parsing midis_emopia/Q1_J6X3rVU1H-c_1.mid
# Parsing midis_emopia/Q1_60LLKmpgzRM_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_9.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_13.mid
# Parsing midis_emopia/Q1_BGf5nCdzPOc_1.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_4.mid
# Parsing midis_emopia/Q1_uqRLEByE6pU_2.mid
# Parsing midis_emopia/Q1_IH2KrGjKXw0_3.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_5.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_1.mid
# Parsing midis_emopia/Q1_Ie5koh4qvJc_6.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_0.mid
# Parsing midis_emopia/Q1_o5AIp2Yc01M_1.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_1.mid
# Parsing midis_emopia/Q1__BK2o77sTc0_1.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_0.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_10.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_0.mid
# Parsing midis_emopia/Q1_GbUV3TXUzeQ_2.mid
# Parsing midis_emopia/Q1_8rupdevqfuI_1.mid
# Parsing midis_emopia/Q1_k4dxAlI5N-k_0.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_0.mid
# Parsing midis_emopia/Q1_k4dxAlI5N-k_1.mid
# Parsing midis_emopia/Q1_NGE9ynTJABg_2.mid
# Parsing midis_emopia/Q1_gwmVjvR-sVs_0.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_0.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_3.mid
# Parsing midis_emopia/Q1_uqRLEByE6pU_0.mid
# Parsing midis_emopia/Q1_iFgSjUqI7iM_0.mid
# Parsing midis_emopia/Q1_NP0lwB-_-og_1.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_0.mid
# Parsing midis_emopia/Q1_GbUV3TXUzeQ_1.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_2.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_3.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_1.mid
# Parsing midis_emopia/Q1_biROWEwkDQQ_3.mid
# Parsing midis_emopia/Q1_Wy2-my19YnY_1.mid
# Parsing midis_emopia/Q1_r6laJv1-HMg_0.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_5.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_6.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_3.mid
# Parsing midis_emopia/Q1_wnB2cjd6zbE_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_1.mid
# Parsing midis_emopia/Q1_JYVXM0qNQAg_2.mid
# Parsing midis_emopia/Q1_6Uf9XBUD3wE_1.mid
# Parsing midis_emopia/Q1_4ydjOX3pWds_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_1.mid
# Parsing midis_emopia/Q1_3ahg_eQZhxs_0.mid
# Parsing midis_emopia/Q1_sZe3IB1OVfw_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_2.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_6.mid
# Parsing midis_emopia/Q1_ldCQ6N9G6Mk_2.mid
# Parsing midis_emopia/Q1_5Ju9q1N2x0E_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_1.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_1.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_2.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_0.mid
# Parsing midis_emopia/Q1_NGE9ynTJABg_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_0.mid
# Parsing midis_emopia/Q1_XC_SiJszQx0_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_8.mid
# Parsing midis_emopia/Q1_KxlqB3j0zys_0.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_1.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_2.mid
# Parsing midis_emopia/Q1_DX1IK3z1w10_1.mid
# Parsing midis_emopia/Q1_sZe3IB1OVfw_0.mid
# Parsing midis_emopia/Q1_qlbazHayULg_8.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_4.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_0.mid
# Parsing midis_emopia/Q1_osxmQReE_2o_0.mid
# Parsing midis_emopia/Q1_4dXC1cC7crw_0.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_3.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_4.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_1.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_0.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_0.mid
# Parsing midis_emopia/Q1_8rupdevqfuI_2.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_1.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_0.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_2.mid
# Parsing midis_emopia/Q1_JYVXM0qNQAg_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_2.mid
# Parsing midis_emopia/Q1_8izVTDgBQPc_1.mid
# Parsing midis_emopia/Q1_o5AIp2Yc01M_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_1.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_2.mid
# Parsing midis_emopia/Q1_Wy2-my19YnY_0.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_14.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_0.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_4.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_0.mid
# Parsing midis_emopia/Q1_iFgSjUqI7iM_1.mid
# Parsing midis_emopia/Q1__8v0MFBZoco_1.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_3.mid
# Parsing midis_emopia/Q1_s6-SbDSZzEU_1.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_0.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_3.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_4.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_1.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_2.mid
# Parsing midis_emopia/Q1_J6X3rVU1H-c_2.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_0.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_0.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_1.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_2.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_11.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_0.mid
# Parsing midis_emopia/Q1__SJQaaRzD-A_0.mid
# Parsing midis_emopia/Q1__BK2o77sTc0_0.mid
# Parsing midis_emopia/Q1_gSwv8hZGM-s_1.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_2.mid
# Parsing midis_emopia/Q1_gSwv8hZGM-s_0.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_2.mid
# Parsing midis_emopia/Q1_Fc1qk52SaKY_1.mid
# Parsing midis_emopia/Q1_mX-xs3OVhTs_0.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_1.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_0.mid
# Parsing midis_emopia/Q1_miqLU2739dk_1.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_1.mid
# Parsing midis_emopia/Q1_V3Y9L4UOcpk_2.mid
# Parsing midis_emopia/Q1_nOIBJHkqrE8_0.mid
# 1/1 [==============================] - 0s 32ms/step
# Parsing midis_emopia/Q1_9v2WSpn4FCw_10.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_3.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_3.mid
# Parsing midis_emopia/Q1_ZgT7yq2jsBk_0.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_3.mid
# Parsing midis_emopia/Q1_POaIGvLsp5M_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_2.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_2.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_1.mid
# Parsing midis_emopia/Q1_3ahg_eQZhxs_1.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_3.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_4.mid
# Parsing midis_emopia/Q1_6Uf9XBUD3wE_0.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_2.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_1.mid
# Parsing midis_emopia/Q1_Cg2u_Ldjv8g_0.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_1.mid
# Parsing midis_emopia/Q1_9Yb9OEVwups_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_3.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_0.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_4.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_2.mid
# Parsing midis_emopia/Q1_K6OFDxBU370_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_0.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_3.mid
# Parsing midis_emopia/Q1_4ydjOX3pWds_0.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_5.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_2.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_12.mid
# Parsing midis_emopia/Q1_xrhWli_R98g_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_7.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_1.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_3.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_2.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_2.mid
# Parsing midis_emopia/Q1_KxlqB3j0zys_1.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_2.mid
# Parsing midis_emopia/Q1_UYh88SRZC24_0.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_0.mid
# Parsing midis_emopia/Q1_UJcnNfeCN1c_2.mid
# Parsing midis_emopia/Q1_gwmVjvR-sVs_1.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_2.mid
# Parsing midis_emopia/Q1_UJcnNfeCN1c_3.mid
# Parsing midis_emopia/Q1_5NW0zDu6IYM_2.mid
# Parsing midis_emopia/Q1_UYh88SRZC24_1.mid
# Parsing midis_emopia/Q1_Ie5koh4qvJc_12.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_0.mid
# Parsing midis_emopia/Q1_Xsn9zT-05ns_1.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_0.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_1.mid
# Parsing midis_emopia/Q1_Xsn9zT-05ns_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_0.mid
# Parsing midis_emopia/Q1_Cg2u_Ldjv8g_1.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_2.mid
# Parsing midis_emopia/Q1_K6OFDxBU370_0.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_0.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_2.mid
# Parsing midis_emopia/Q1_sUJ4a74Skk8_0.mid
# Parsing midis_emopia/Q1_e8NQ2NH0nc8_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_15.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_3.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_1.mid
# Parsing midis_emopia/Q1_T92R7xjce34_1.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_2.mid
# Parsing midis_emopia/Q1_xrhWli_R98g_1.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_1.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_1.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_1.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_3.mid
# Parsing midis_emopia/Q1_BGf5nCdzPOc_0.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_0.mid
# Parsing midis_emopia/Q1_mX-xs3OVhTs_1.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_5.mid
# Parsing midis_emopia/Q1_QwsQ8ejbMKg_0.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_5.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_0.mid
# Parsing midis_emopia/Q1__SJQaaRzD-A_1.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_1.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_4.mid
# Parsing midis_emopia/Q1_s6-SbDSZzEU_0.mid
# Parsing midis_emopia/Q1_POaIGvLsp5M_0.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_0.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_2.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_2.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_2.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_1.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_3.mid
# Parsing midis_emopia/Q1_4dXC1cC7crw_1.mid
# Parsing midis_emopia/Q1_e8NQ2NH0nc8_0.mid
# Parsing midis_emopia/Q1__8v0MFBZoco_0.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_1.mid
# Parsing midis_emopia/Q1_6wFJhmhNeeg_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_3.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_0.mid
# Parsing midis_emopia/Q1_Fc1qk52SaKY_0.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_1.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_2.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_1.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_2.mid
# Parsing midis_emopia/Q1_SlsXsqotUis_0.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_1.mid
# Parsing midis_emopia/Q1_cB-Xh8H_7-Q_0.mid
# Parsing midis_emopia/Q1_J6X3rVU1H-c_1.mid
# Parsing midis_emopia/Q1_60LLKmpgzRM_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_9.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_13.mid
# Parsing midis_emopia/Q1_BGf5nCdzPOc_1.mid
# Parsing midis_emopia/Q1_7yW9c7t8Hq0_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_4.mid
# Parsing midis_emopia/Q1_uqRLEByE6pU_2.mid
# Parsing midis_emopia/Q1_IH2KrGjKXw0_3.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_5.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_1.mid
# Parsing midis_emopia/Q1_Ie5koh4qvJc_6.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_0.mid
# Parsing midis_emopia/Q1_o5AIp2Yc01M_1.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_1.mid
# Parsing midis_emopia/Q1__BK2o77sTc0_1.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_0.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_10.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_0.mid
# Parsing midis_emopia/Q1_GbUV3TXUzeQ_2.mid
# Parsing midis_emopia/Q1_8rupdevqfuI_1.mid
# Parsing midis_emopia/Q1_k4dxAlI5N-k_0.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_0.mid
# Parsing midis_emopia/Q1_k4dxAlI5N-k_1.mid
# Parsing midis_emopia/Q1_NGE9ynTJABg_2.mid
# Parsing midis_emopia/Q1_gwmVjvR-sVs_0.mid
# Parsing midis_emopia/Q1_dfNdpy8TUzA_0.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_3.mid
# Parsing midis_emopia/Q1_uqRLEByE6pU_0.mid
# Parsing midis_emopia/Q1_iFgSjUqI7iM_0.mid
# Parsing midis_emopia/Q1_NP0lwB-_-og_1.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_0.mid
# Parsing midis_emopia/Q1_GbUV3TXUzeQ_1.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_2.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_3.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_1.mid
# Parsing midis_emopia/Q1_biROWEwkDQQ_3.mid
# Parsing midis_emopia/Q1_Wy2-my19YnY_1.mid
# Parsing midis_emopia/Q1_r6laJv1-HMg_0.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_5.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_6.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_3.mid
# Parsing midis_emopia/Q1_wnB2cjd6zbE_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_1.mid
# Parsing midis_emopia/Q1_JYVXM0qNQAg_2.mid
# Parsing midis_emopia/Q1_6Uf9XBUD3wE_1.mid
# Parsing midis_emopia/Q1_4ydjOX3pWds_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_1.mid
# Parsing midis_emopia/Q1_3ahg_eQZhxs_0.mid
# Parsing midis_emopia/Q1_sZe3IB1OVfw_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_2.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_6.mid
# Parsing midis_emopia/Q1_ldCQ6N9G6Mk_2.mid
# Parsing midis_emopia/Q1_5Ju9q1N2x0E_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_1.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_1.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_2.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_0.mid
# Parsing midis_emopia/Q1_NGE9ynTJABg_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_0.mid
# Parsing midis_emopia/Q1_XC_SiJszQx0_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_8.mid
# Parsing midis_emopia/Q1_KxlqB3j0zys_0.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_1.mid
# Parsing midis_emopia/Q1_PdwxeMPXOCk_2.mid
# Parsing midis_emopia/Q1_DX1IK3z1w10_1.mid
# Parsing midis_emopia/Q1_sZe3IB1OVfw_0.mid
# Parsing midis_emopia/Q1_qlbazHayULg_8.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_2.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_4.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_0.mid
# Parsing midis_emopia/Q1_osxmQReE_2o_0.mid
# Parsing midis_emopia/Q1_4dXC1cC7crw_0.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_3.mid
# Parsing midis_emopia/Q1_zHwJG8Rrx6c_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_4.mid
# Parsing midis_emopia/Q1_RaUSISlnhKw_1.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_0.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_0.mid
# Parsing midis_emopia/Q1_8rupdevqfuI_2.mid
# Parsing midis_emopia/Q1_94ROf10d1iA_1.mid
# Parsing midis_emopia/Q1_6kRPHamGDSo_0.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_2.mid
# Parsing midis_emopia/Q1_JYVXM0qNQAg_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_2.mid
# Parsing midis_emopia/Q1_8izVTDgBQPc_1.mid
# Parsing midis_emopia/Q1_o5AIp2Yc01M_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_1.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_2.mid
# Parsing midis_emopia/Q1_Wy2-my19YnY_0.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_0.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_14.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_0.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_4.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_1.mid
# Parsing midis_emopia/Q1_zmZHNy9T8Pg_0.mid
# Parsing midis_emopia/Q1_iFgSjUqI7iM_1.mid
# Parsing midis_emopia/Q1__8v0MFBZoco_1.mid
# Parsing midis_emopia/Q1_3N2G21U7guk_3.mid
# Parsing midis_emopia/Q1_s6-SbDSZzEU_1.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_0.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_3.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_4.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_1.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_2.mid
# Parsing midis_emopia/Q1_J6X3rVU1H-c_2.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_0.mid
# Parsing midis_emopia/Q1_pNwQ9Tu_bCs_0.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_1.mid
# Parsing midis_emopia/Q1_UOSlDydo94E_2.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_11.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_0.mid
# Parsing midis_emopia/Q1__SJQaaRzD-A_0.mid
# Parsing midis_emopia/Q1__BK2o77sTc0_0.mid
# Parsing midis_emopia/Q1_gSwv8hZGM-s_1.mid
# Parsing midis_emopia/Q1_WpZ1rWHOCAQ_2.mid
# Parsing midis_emopia/Q1_gSwv8hZGM-s_0.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_2.mid
# Parsing midis_emopia/Q1_Fc1qk52SaKY_1.mid
# Parsing midis_emopia/Q1_mX-xs3OVhTs_0.mid
# Parsing midis_emopia/Q1_yFw_kO7DF-Y_1.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_1.mid
# Parsing midis_emopia/Q1_s5b8viFsVJE_0.mid
# Parsing midis_emopia/Q1_miqLU2739dk_1.mid
# Parsing midis_emopia/Q1_0vLPYiPN7qY_1.mid
# Parsing midis_emopia/Q1_V3Y9L4UOcpk_2.mid
# Parsing midis_emopia/Q1_nOIBJHkqrE8_0.mid
# 1/1 [==============================] - 0s 19ms/step
# Parsing midis_emopia/Q1_9v2WSpn4FCw_10.mid
# Parsing midis_emopia/Q1_Y5JcZQ0xg4Y_3.mid
# Parsing midis_emopia/Q1_1Qc15G0ZHIg_3.mid
# Parsing midis_emopia/Q1_ZgT7yq2jsBk_0.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_3.mid
# Parsing midis_emopia/Q1_POaIGvLsp5M_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_2.mid
# Parsing midis_emopia/Q1_1vjy9oMFa8c_2.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_1.mid
# Parsing midis_emopia/Q1_3ahg_eQZhxs_1.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_3.mid
# Parsing midis_emopia/Q1_fey-8bOR95E_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_4.mid
# Parsing midis_emopia/Q1_6Uf9XBUD3wE_0.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_2.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_1.mid
# Parsing midis_emopia/Q1_Cg2u_Ldjv8g_0.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_1.mid
# Parsing midis_emopia/Q1_9Yb9OEVwups_0.mid
# Parsing midis_emopia/Q1_vv6nrZ2myXw_3.mid
# Parsing midis_emopia/Q1_im4Qxn3GQvo_0.mid
# Parsing midis_emopia/Q1_aYe-2Glruu4_4.mid
# Parsing midis_emopia/Q1_bQS8eAXAhyE_2.mid
# Parsing midis_emopia/Q1_K6OFDxBU370_1.mid
# Parsing midis_emopia/Q1_eVMSeElk81Q_0.mid
# Parsing midis_emopia/Q1_e838BE_MH6s_3.mid
# Parsing midis_emopia/Q1_4ydjOX3pWds_0.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_5.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_2.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_12.mid
# Parsing midis_emopia/Q1_xrhWli_R98g_3.mid
# Parsing midis_emopia/Q1_2Z9SjI131jA_7.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_1.mid
# Parsing midis_emopia/Q1_VXgRfsVd_o0_2.mid
# Parsing midis_emopia/Q1_FfwKrQyQ7WU_3.mid
# Parsing midis_emopia/Q1_JT1XJnVmABo_2.mid
# Parsing midis_emopia/Q1_Jn9r0avp0fY_2.mid
# Parsing midis_emopia/Q1_KxlqB3j0zys_1.mid
# Parsing midis_emopia/Q1_HY9vPoHbgaI_2.mid
# Parsing midis_emopia/Q1_UYh88SRZC24_0.mid
# Parsing midis_emopia/Q1_GY3f6ckBVkA_0.mid
# Parsing midis_emopia/Q1_UJcnNfeCN1c_2.mid
# Parsing midis_emopia/Q1_gwmVjvR-sVs_1.mid
# Parsing midis_emopia/Q1_TNoaOTrTkTQ_2.mid
# Parsing midis_emopia/Q1_doM_LWo-74A_2.mid
# Parsing midis_emopia/Q1_UJcnNfeCN1c_3.mid
# Parsing midis_emopia/Q1_5NW0zDu6IYM_2.mid
# Parsing midis_emopia/Q1_UYh88SRZC24_1.mid
# Parsing midis_emopia/Q1_Ie5koh4qvJc_12.mid
# Parsing midis_emopia/Q1_9v2WSpn4FCw_0.mid
# Parsing midis_emopia/Q1_Xsn9zT-05ns_1.mid
# Parsing midis_emopia/Q1_ANZf1QXsNrY_0.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_1.mid
# Parsing midis_emopia/Q1_Xsn9zT-05ns_0.mid
# Parsing midis_emopia/Q1_bIx4DwkZxFY_0.mid
# Parsing midis_emopia/Q1_Cg2u_Ldjv8g_1.mid
# Parsing midis_emopia/Q1_SQDuF0qxGQw_2.mid
# Parsing midis_emopia/Q1_K6OFDxBU370_0.mid
# Parsing midis_emopia/Q1__kJtgm1OUNA_0.mid
# Parsing midis_emopia/Q1_jziI_cuN_H8_2.mid
# Parsing midis_emopia/Q1_sUJ4a74Skk8_0.mid
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/Transformer_GANs_music_generation/gans_generate.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell://codespaces%2Bturbo-sniffle-6q7g974vg7vcrjrx/workspaces/Transformer_GANs_music_generation/gans_generate.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> # Generate new music sequence
#      <a href='vscode-notebook-cell://codespaces%2Bturbo-sniffle-6q7g974vg7vcrjrx/workspaces/Transformer_GANs_music_generation/gans_generate.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> for i in range(5):
# ---> <a href='vscode-notebook-cell://codespaces%2Bturbo-sniffle-6q7g974vg7vcrjrx/workspaces/Transformer_GANs_music_generation/gans_generate.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     generated_music = generate_music(generator_model, LATENT_DIMENSION, n_vocab)
#      <a href='vscode-notebook-cell://codespaces%2Bturbo-sniffle-6q7g974vg7vcrjrx/workspaces/Transformer_GANs_music_generation/gans_generate.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>     # Create a MIDI file from the generated music
#      <a href='vscode-notebook-cell://codespaces%2Bturbo-sniffle-6q7g974vg7vcrjrx/workspaces/Transformer_GANs_music_generation/gans_generate.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>     create_midi(generated_music, filename="generated_music_Q1_" + str(i) + ".mid")
#
# File /workspaces/Transformer_GANs_music_generation/gans_generation.py:52, in generate_music(generator_model, latent_dim, n_vocab, length, emotion)
#      49 pred_notes = [x * (n_vocab / 2) + (n_vocab / 2) for x in predictions[0]]
#      51 # Map generated integer indices to note names
# ---> 52 notes = get_notes(emotion)
#      53 pitchnames = sorted(set(item for item in notes))
#      54 int_to_note = dict((number, note) for number, note in enumerate(pitchnames))
#
# File /workspaces/Transformer_GANs_music_generation/gans_transformer.py:21, in get_notes(emotion)
#      19 midi = converter.parse(file)
#      20 print("Parsing %s" % file)
# ---> 21 notes_to_parse = midi.flat.notes
#      23 for element in notes_to_parse:
#      24     if isinstance(element, note.Note):
#
# File ~/.python/current/lib/python3.10/site-packages/music21/stream/base.py:8047, in Stream.flat(self)
#    8037 @property
#    8038 def flat(self):
#    8039     '''
#    8040     Deprecated: use `.flatten()` instead
#    8041
#    (...)
#    8045     See :meth:`~music21.stream.base.Stream.flatten()` for documentation.
#    8046     '''
# -> 8047     flatStream = self.flatten(retainContainers=False)
#    8048     flatStream._created_via_deprecated_flat = True
#    8049     return flatStream
#
# File ~/.python/current/lib/python3.10/site-packages/music21/stream/base.py:8029, in Stream.flatten(self, retainContainers)
#    8026     sNew.isFlat = True
#    8028 if self.autoSort is True:
# -> 8029     sNew.sort()  # sort it immediately so that cache is not invalidated
#    8030 else:
#    8031     sNew.coreElementsChanged()
#
# File ~/.python/current/lib/python3.10/site-packages/music21/stream/base.py:7646, in Stream.sort(self, force)
#    7643 # trust if this is sorted: do not sort again
#    7644 # experimental
#    7645 if (not self.isSorted and self._mutable) or force:
# -> 7646     self._elements.sort(key=lambda x: x.sortTuple(self))
#    7647     self._endElements.sort(key=lambda x: x.sortTuple(self))
#    7649     # as sorting changes order, elements have changed;
#    7650     # need to clear cache, but flat status is the same
#
# File ~/.python/current/lib/python3.10/site-packages/music21/stream/base.py:7646, in Stream.sort.<locals>.<lambda>(x)
#    7643 # trust if this is sorted: do not sort again
#    7644 # experimental
#    7645 if (not self.isSorted and self._mutable) or force:
# -> 7646     self._elements.sort(key=lambda x: x.sortTuple(self))
#    7647     self._endElements.sort(key=lambda x: x.sortTuple(self))
#    7649     # as sorting changes order, elements have changed;
#    7650     # need to clear cache, but flat status is the same
#
# File ~/.python/current/lib/python3.10/site-packages/music21/base.py:2740, in Music21Object.sortTuple(self, useSite, raiseExceptionOnMiss)
#    2737 else:  # for None, use this instead of default of -2.
#    2738     insertIndex = 0
# -> 2740 return SortTuple(atEnd, offset, self.priority,
#    2741                   self.classSortOrder, isNotGrace, insertIndex)
#
# KeyboardInterrupt:

# %%
from music21 import converter, instrument, note, chord, stream
for i in range(5):
    file = converter.parse('/workspaces/Transformer_GANs_music_generation/generated_music_Q1_' + str(i) + '.mid' + '.mid') 
    file.show('midi')
# Out:
#         <div id="midiPlayerDiv1286927"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv1286927_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv1286927");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv1286927_play, 2000);
#         } else {
#             midiPlayerDiv1286927_play();
#         }
#         </script>
#         <div id="midiPlayerDiv1288468"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv1288468_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv1288468");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv1288468_play, 2000);
#         } else {
#             midiPlayerDiv1288468_play();
#         }
#         </script>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /workspaces/Transformer_GANs_music_generation/gans_generate.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell://codespaces%2Bturbo-sniffle-6q7g974vg7vcrjrx/workspaces/Transformer_GANs_music_generation/gans_generate.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from music21 import converter, instrument, note, chord, stream
#       <a href='vscode-notebook-cell://codespaces%2Bturbo-sniffle-6q7g974vg7vcrjrx/workspaces/Transformer_GANs_music_generation/gans_generate.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> for i in range(5):
# ----> <a href='vscode-notebook-cell://codespaces%2Bturbo-sniffle-6q7g974vg7vcrjrx/workspaces/Transformer_GANs_music_generation/gans_generate.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     file = converter.parse('/workspaces/Transformer_GANs_music_generation/generated_music_Q1_' + str(i) + '.mid' + '.mid')
#       <a href='vscode-notebook-cell://codespaces%2Bturbo-sniffle-6q7g974vg7vcrjrx/workspaces/Transformer_GANs_music_generation/gans_generate.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     file.show('midi')
#
# File ~/.python/current/lib/python3.10/site-packages/music21/converter/__init__.py:1424, in parse(value, forceSource, number, format, **keywords)
#    1421     raise FileNotFoundError(f'Cannot find file in {str(value)}')
#    1422 elif isinstance(value, str) and common.findFormatFile(value) is not None:
#    1423     # assume mistyped file path
# -> 1424     raise FileNotFoundError(f'Cannot find file in {str(value)}')
#    1425 else:
#    1426     # all else, including MidiBytes
#    1427     return parseData(value, number=number, format=format, **keywords)
#
# FileNotFoundError: Cannot find file in /workspaces/Transformer_GANs_music_generation/generated_music_Q1_2.mid.mid
